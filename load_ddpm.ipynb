# %%
import torch
from diffusion_mnist.models import ContextUnet
from diffusion_mnist import Hyperparameters

# %%
model = ContextUnet().to(Hyperparameters.DEVICE)

# load in model weights and set to eval mode
model.load_state_dict(torch.load(f"weights/ddpm.pth", map_location=Hyperparameters.DEVICE))
# Out:
# <All keys matched successfully>
